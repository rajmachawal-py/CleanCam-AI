# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n model

train_results = model.train(
    data = "C:\\Users\\Lakshay\\Desktop\\Portfolio\\CleanCam AI\\Garbage_dataset\\data.yaml",
    epochs = 10,
    imgsz = 640,
    device='cpu'
)
# Out:
# Ultralytics 8.3.241  Python-3.12.9 torch-2.9.1+cpu CPU (AMD Ryzen 7 7435HS)
# ...

# %%
from ultralytics import YOLO    
model = YOLO('C:\\Users\\Lakshay\\Desktop\\Portfolio\\CleanCam AI\\src\\runs\\detect\\train5\\weights\\best.pt')  # load a custom model

results = model("test_images", save=True)  # predict on an image
results[0].show()  # show results for first image
# Out:
# image 1/5 c:\Users\Lakshay\Desktop\Portfolio\CleanCam AI\src\test_images\test1.jpg: 448x640 1 garbage, 62.8ms
# image 2/5 c:\Users\Lakshay\Desktop\Portfolio\CleanCam AI\src\test_images\test2.jpg: 448x640 1 garbage, 33.2ms
# image 3/5 c:\Users\Lakshay\Desktop\Portfolio\CleanCam AI\src\test_images\test3.jpg: 448x640 2 garbages, 35.8ms
# image 4/5 c:\Users\Lakshay\Desktop\Portfolio\CleanCam AI\src\test_images\test4.jpg: 448x640 1 garbage, 35.3ms
# image 5/5 c:\Users\Lakshay\Desktop\Portfolio\CleanCam AI\src\test_images\test5.jpg: 384x640 1 garbage, 42.1ms
# Speed: 2.1ms preprocess, 41.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\Users\Lakshay\Desktop\Portfolio\CleanCam AI\src\runs\detect\predict
